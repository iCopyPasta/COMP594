# %%
'''# Code to write files depending on the machine we are using
import os
from datetime import datetime
import logging

BASE_PATH = "/home/peo5032/Documents/COMP594"
MACHINE_NAME = os.uname()[1]
WRITE_ROOT = BASE_PATH + "/" + MACHINE_NAME
SESSION_INSTANCE = WRITE_ROOT + "/" + str(datetime.now())
# Logging setup and File
FILE_NAME = "run_information.log"
logging.basicConfig(filename=FILE_NAME, level=logging.DEBUG)

try:
    os.mkdir(BASE_PATH)
    logging.debug('successfully wrote ' + BASE_PATH)
except FileExistsError:
    logging.debug('we already have this path created!')
except OSError:
    logging.debug('something happened that it couldnt create this path?')

try:
    os.mkdir(WRITE_ROOT)
    logging.debug('successfully wrote ' +  WRITE_ROOT)
except FileExistsError:
    logging.debug('we already have this path created!')
except OSError:
    logging.debug('something happened that it couldnt create this path?') 
    
    
try:
    os.mkdir(SESSION_INSTANCE)
    logging.debug('successfully wrote' + SESSION_INSTANCE)
except FileExistsError:
    logging.debug('we already have this path created!')
except OSError:
    logging.debug('something happened that it couldnt create this path?') 
'''

# %%
#read our excel file
import pandas as pd

df = pd.read_excel("./reference_code/Route_segments_urban_lanes_region.xlsx")

# %%
#create our types
df.sort_values('URBAN')
# Out:
#        ROUTE   BEGARM   ENDARM  URBAN  TWO LANE         REGION  \
# 3430      97     37.0    38.00      0         1  South Central
# 4206     109      7.0     8.00      0         1        Olympic
# 4205     109      6.0     7.00      0         1        Olympic
# 4204     109      5.0     6.00      0         1        Olympic
# 4203     109      4.0     5.00      0         1        Olympic
# 4198     108     11.0    11.92      0         0        Olympic
# 4197     108     10.0    11.00      0         1        Olympic
# 4196     108      9.0    10.00      0         1        Olympic
# 4195     108      8.0     9.00      0         1        Olympic
# 4194     108      7.0     8.00      0         1        Olympic
# 4193     108      6.0     7.00      0         1        Olympic
# 4192     108      5.0     6.00      0         1        Olympic
# 4191     108      4.0     5.00      0         1        Olympic
# 4190     108      3.0     4.00      0         1        Olympic
# 4189     108      2.0     3.00      0         1        Olympic
# 4188     108      1.0     2.00      0         1        Olympic
# 4187     108      0.0     1.00      0         1        Olympic
# 4186     107      7.0     7.83      0         1        Olympic
# 4185     107      6.0     7.00      0         1        Olympic
# 4184     107      5.0     6.00      0         1        Olympic
# 4207     109      8.0     9.00      0         1        Olympic
# 4208     109      9.0    10.00      0         1        Olympic
# 4209     109     10.0    11.00      0         1        Olympic
# 4210     109     11.0    12.00      0         1        Olympic
# 4230     109     31.0    32.00      0         1        Olympic
# 4229     109     30.0    31.00      0         1        Olympic
# 4228     109     29.0    30.00      0         1        Olympic
# 4227     109     28.0    29.00      0         1        Olympic
# 4226     109     27.0    28.00      0         1        Olympic
# 876                      Two-Lane-URBAN
# 5586  Non-Two-Lane-Non-Interstate-URBAN
# 875                      Two-Lane-URBAN
# 873                      Two-Lane-URBAN
# 851   Non-Two-Lane-Non-Interstate-URBAN
# 852   Non-Two-Lane-Non-Interstate-URBAN
# 853   Non-Two-Lane-Non-Interstate-URBAN
# 854   Non-Two-Lane-Non-Interstate-URBAN
# 855                      Two-Lane-URBAN
# 856                      Two-Lane-URBAN
# 857                      Two-Lane-URBAN
# 858   Non-Two-Lane-Non-Interstate-URBAN
# 859   Non-Two-Lane-Non-Interstate-URBAN
# 860                      Two-Lane-URBAN
# 861                      Two-Lane-URBAN
# 862                      Two-Lane-URBAN
# 5565                     Two-Lane-URBAN
# 863                      Two-Lane-URBAN
# 864   Non-Two-Lane-Non-Interstate-URBAN
# 865   Non-Two-Lane-Non-Interstate-URBAN
# 866   Non-Two-Lane-Non-Interstate-URBAN
# 867   Non-Two-Lane-Non-Interstate-URBAN
# 868   Non-Two-Lane-Non-Interstate-URBAN
# 869                      Two-Lane-URBAN
# 870                      Two-Lane-URBAN
# 871                      Two-Lane-URBAN
# 872                      Two-Lane-URBAN
# 874                      Two-Lane-URBAN
# 0     Non-Two-Lane-Non-Interstate-URBAN
#
# [6861 rows x 7 columns]

# %%
with open('/home/peo5032/Documents/COMP594/urban_list.txt', 'w') as urban, open('/home/peo5032/Documents/COMP594/non_urban_list.txt', 'w') as non_urban:
#route, begarm, endarm, urban, two lane, region, functional class
    for index, row in df.iterrows():
        tmp = str(row[0]) + '_' + str(int(row[1]))
        if row[3] == 1:
            for i in range(0,100):
                urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_b.png' + " /home/peo5032/Documents/COMP594/URBAN_IMAGES" + '\n')
                urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_i.png' + " /home/peo5032/Documents/COMP594/URBAN_IMAGES" + '\n')
                urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_d.png' + " /home/peo5032/Documents/COMP594/URBAN_IMAGES" + '\n')
        else:
            for i in range(0,100):
                non_urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_b.png'  + " /home/peo5032/Documents/COMP594/NON_URBAN_IMAGES" + '\n')
                non_urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_i.png'  + " /home/peo5032/Documents/COMP594/NON_URBAN_IMAGES" + '\n')
                non_urban.write("cp /home/jjb24/wsdot/input/images/" + tmp + '.' + str(i) + '_d.png'  + " /home/peo5032/Documents/COMP594/NON_URBAN_IMAGES" + '\n')

        
    urban.close()
    non_urban.close()
